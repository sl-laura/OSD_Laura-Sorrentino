# %% [markdown]
# # __ANALISI DEL TASSO DI OCCUPAZIONE GIOVANILE IN ITALIA NEGLI ANNI 2010 - 2019__

# %% [markdown]
# **Esercizio laboratorio per i punti aggiuntivi all'esame di Alice Ilacqua, Laura Sorrentino e Colombo Rebecca**

# %% [markdown]
# Il dataset fa riferimento al tasso di occupazione giovanile italiana negli anni 2010 - 2019 raggruppata per età 15-24 e 25-34 anni ; abbiamo deciso di analizzare tale datasat in quanto ci ha interessato l'argomento e abbiamo deciso di approfondirlo utilizzando le competenze acquisite durante le lezioni e durante i vari esercizi svolti

# %% [markdown]
# Il dataset utilizzato si può trovare sul sito ISTAT cliccando il seguente link: http://dati-giovani.istat.it/ PERCORSO DA SEGUIRE PER VISUALIZZARE TABELLA: Lavoro--Occupazione--Tasso di occupazione--Popolazione di 15-34 anni - reg.-- selezionare periodo 2010 - 2019 togliendo i trimestri --selezionare fasce età 15-24 e 25-34)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread("C:/Users/lalla/Desktop/UNIMI/OIP.jpg")

# %%
imgplot = plt.imshow(img)

# %%
plt.figure(figsize=(15,15))
plt.imshow(img); plt.show()

# %%
import numpy as np
import pandas as pd

# %%
tabella_iniziale_occ = pd.read_csv("C:/Users/lalla/Desktop/UNIMI/Tasso occupazione.csv")
tabella_iniziale_occ
# Out:
#      ITTER107 Territorio  SEXISTAT1    Sesso    ETA1 Classe di età  TIME  \
# 0        ITC1   Piemonte          1   maschi  Y15-24    15-24 anni  2010
# 1        ITC1   Piemonte          1   maschi  Y15-24    15-24 anni  2011
# 2        ITC1   Piemonte          1   maschi  Y15-24    15-24 anni  2012
# 3        ITC1   Piemonte          1   maschi  Y15-24    15-24 anni  2013
# 4        ITC1   Piemonte          1   maschi  Y15-24    15-24 anni  2014
# ...       ...        ...        ...      ...     ...           ...   ...
# 1315     ITE2     Umbria          2  femmine  Y25-34    25-34 anni  2015
# 1316     ITE2     Umbria          2  femmine  Y25-34    25-34 anni  2016
# 1317     ITE2     Umbria          2  femmine  Y25-34    25-34 anni  2017
# 1318     ITE2     Umbria          2  femmine  Y25-34    25-34 anni  2018
# 1319     ITE2     Umbria          2  femmine  Y25-34    25-34 anni  2019
#
#       Seleziona periodo   Value  Flag Codes  Flags
# 0                  2010  52.110         NaN    NaN
# 1                  2011  54.017         NaN    NaN
# 2                  2012  52.224         NaN    NaN
# 3                  2013  42.618         NaN    NaN
# 4                  2014  39.999         NaN    NaN
# ...                 ...     ...         ...    ...
# 1315               2015  28.447         NaN    NaN
# 1316               2016  29.167         NaN    NaN
# 1317               2017  26.733         NaN    NaN
# 1318               2018  24.818         NaN    NaN
# 1319               2019  28.554         NaN    NaN
#
# [1320 rows x 11 columns]

# %%
tabella_iniziale_occ.isnull().sum()
# Out:
# ITTER107                0
# Territorio              0
# SEXISTAT1               0
# Sesso                   0
# ETA1                    0
# Classe di età           0
# TIME                    0
# Seleziona periodo       0
# Value                   0
# Flag Codes           1320
# Flags                1320
# dtype: int64

# %% [markdown]
#  **Tutti i valori di "Flag Codes" e "Flag" sono nulli (1320) pertanto eliminiamo le due colonne perchè non ci interessano per la nostra analisi e creiamo un nuovo dataset con le colonne che ci interessano**

# %%
tasso_occupazione_giovanile= pd.DataFrame(data=tabella_iniziale_occ, columns =['Territorio', 'SEXISTAT1', 'Sesso', 'Classe di età', 'Seleziona periodo', 'Value' ])
tasso_occupazione_giovanile
# Out:
#      Territorio  SEXISTAT1    Sesso Classe di età  Seleziona periodo   Value
# 0      Piemonte          1   maschi    15-24 anni               2010  52.110
# 1      Piemonte          1   maschi    15-24 anni               2011  54.017
# 2      Piemonte          1   maschi    15-24 anni               2012  52.224
# 3      Piemonte          1   maschi    15-24 anni               2013  42.618
# 4      Piemonte          1   maschi    15-24 anni               2014  39.999
# ...         ...        ...      ...           ...                ...     ...
# 1315     Umbria          2  femmine    25-34 anni               2015  28.447
# 1316     Umbria          2  femmine    25-34 anni               2016  29.167
# 1317     Umbria          2  femmine    25-34 anni               2017  26.733
# 1318     Umbria          2  femmine    25-34 anni               2018  24.818
# 1319     Umbria          2  femmine    25-34 anni               2019  28.554
#
# [1320 rows x 6 columns]

# %% [markdown]
# **La tabella non ci evidenzia la fascia di età 25-34 ma in realtà i valori ci sono (vedi sotto):**

# %%
Età= tasso_occupazione_giovanile.groupby(["Classe di età"]).count().reset_index()
Età["Classe di età"]
# Out:
# 0    15-24 anni
# 1    25-34 anni
# Name: Classe di età, dtype: object

# %%
#rinominiamo "Value" con "Valori" almeno abbiamo tutte le colonne in italiano
tasso_occupazione_giovanile.rename(columns={"Value": "Valori"},inplace=True) 
tasso_occupazione_giovanile
# Out:
#      Territorio  SEXISTAT1    Sesso Classe di età  Seleziona periodo  Valori
# 0      Piemonte          1   maschi    15-24 anni               2010  52.110
# 1      Piemonte          1   maschi    15-24 anni               2011  54.017
# 2      Piemonte          1   maschi    15-24 anni               2012  52.224
# 3      Piemonte          1   maschi    15-24 anni               2013  42.618
# 4      Piemonte          1   maschi    15-24 anni               2014  39.999
# ...         ...        ...      ...           ...                ...     ...
# 1315     Umbria          2  femmine    25-34 anni               2015  28.447
# 1316     Umbria          2  femmine    25-34 anni               2016  29.167
# 1317     Umbria          2  femmine    25-34 anni               2017  26.733
# 1318     Umbria          2  femmine    25-34 anni               2018  24.818
# 1319     Umbria          2  femmine    25-34 anni               2019  28.554
#
# [1320 rows x 6 columns]

# %% [markdown]
# Il primo passaggio da fare è verificare se nel dataset sono presenti tutte le regioni utilizzando la funzione "groupby"

# %%
Territori=tasso_occupazione_giovanile.groupby(["Territorio"]).count().reset_index()
Territori["Territorio"]
# Out:
# 0                                Abruzzo
# 1                             Basilicata
# 2                               Calabria
# 3                               Campania
# 4                         Emilia-Romagna
# 5                  Friuli-Venezia Giulia
# 6                                  Lazio
# 7                                Liguria
# 8                              Lombardia
# 9                                 Marche
# 10                                Molise
# 11                              Piemonte
# 12    Provincia Autonoma Bolzano / Bozen
# 13             Provincia Autonoma Trento
# 14                                Puglia
# 15                              Sardegna
# 16                               Sicilia
# 17                               Toscana
# 18        Trentino Alto Adige / Südtirol
# 19                                Umbria
# 20        Valle d'Aosta / Vallée d'Aoste
# 21                                Veneto
# Name: Territorio, dtype: object

# %% [markdown]
# Come si può notare, le due Province di Bolzano e Trento rientrano nella regione del Trentino Alto Adige quindi le cancelliamo dal dataset:

# %%
#TOG="tasso occupazione giovanile"
TOG_regioni=tasso_occupazione_giovanile[~tasso_occupazione_giovanile.Territorio.str.contains("Provincia")]
TOG_regioni
# Out:
#      Territorio  SEXISTAT1    Sesso Classe di età  Seleziona periodo  Valori
# 0      Piemonte          1   maschi    15-24 anni               2010  52.110
# 1      Piemonte          1   maschi    15-24 anni               2011  54.017
# 2      Piemonte          1   maschi    15-24 anni               2012  52.224
# 3      Piemonte          1   maschi    15-24 anni               2013  42.618
# 4      Piemonte          1   maschi    15-24 anni               2014  39.999
# ...         ...        ...      ...           ...                ...     ...
# 1315     Umbria          2  femmine    25-34 anni               2015  28.447
# 1316     Umbria          2  femmine    25-34 anni               2016  29.167
# 1317     Umbria          2  femmine    25-34 anni               2017  26.733
# 1318     Umbria          2  femmine    25-34 anni               2018  24.818
# 1319     Umbria          2  femmine    25-34 anni               2019  28.554
#
# [1200 rows x 6 columns]

# %% [markdown]
# **Il mio dataset adesso è TOG_regioni quindi poi posso creare altri dataset partendo da questo**

# %%
primo_data=TOG_regioni[['Territorio', 'Sesso', 'Valori', 'Classe di età']]
primo_data
# Out:
#      Territorio    Sesso  Valori Classe di età
# 0      Piemonte   maschi  52.110    15-24 anni
# 1      Piemonte   maschi  54.017    15-24 anni
# 2      Piemonte   maschi  52.224    15-24 anni
# 3      Piemonte   maschi  42.618    15-24 anni
# 4      Piemonte   maschi  39.999    15-24 anni
# ...         ...      ...     ...           ...
# 1315     Umbria  femmine  28.447    25-34 anni
# 1316     Umbria  femmine  29.167    25-34 anni
# 1317     Umbria  femmine  26.733    25-34 anni
# 1318     Umbria  femmine  24.818    25-34 anni
# 1319     Umbria  femmine  28.554    25-34 anni
#
# [1200 rows x 4 columns]

# %%
sesso_femmine=primo_data[primo_data.Sesso == ["femmine"]
sesso_femmine
# Out:
#   File "<ipython-input-16-7c51af81a10a>", line 2
#     sesso_femmine
#     ^
# SyntaxError: invalid syntax

# %%
sesso_femmine=primo_data.loc[(primo_data['Sesso'] =='femmine') & (primo_data['Classe di età']=='15-24')]
sesso_femmine
# Out:
# Empty DataFrame
# Columns: [Territorio, Sesso, Valori, Classe di età]
# Index: []

# %%
sesso_maschi=primo_data[primo_data.Sesso == "maschi"] 
sesso_maschi
# Out:
#      Territorio   Sesso   Valori Classe di età
# 0      Piemonte  maschi   52.110    15-24 anni
# 1      Piemonte  maschi   54.017    15-24 anni
# 2      Piemonte  maschi   52.224    15-24 anni
# 3      Piemonte  maschi   42.618    15-24 anni
# 4      Piemonte  maschi   39.999    15-24 anni
# ...         ...     ...      ...           ...
# 1255   Campania  maschi  189.280    25-34 anni
# 1256   Campania  maschi  188.216    25-34 anni
# 1257   Campania  maschi  197.880    25-34 anni
# 1258   Campania  maschi  191.159    25-34 anni
# 1259   Campania  maschi  191.087    25-34 anni
#
# [400 rows x 4 columns]

# %%
totale=primo_data[primo_data.Sesso == "totale"]
totale
# Out:
#      Territorio   Sesso  Valori Classe di età
# 20     Piemonte  totale  92.305    15-24 anni
# 21     Piemonte  totale  93.164    15-24 anni
# 22     Piemonte  totale  88.688    15-24 anni
# 23     Piemonte  totale  71.562    15-24 anni
# 24     Piemonte  totale  70.225    15-24 anni
# ...         ...     ...     ...           ...
# 1305    Liguria  totale  95.891    25-34 anni
# 1306    Liguria  totale  92.441    25-34 anni
# 1307    Liguria  totale  94.548    25-34 anni
# 1308    Liguria  totale  98.542    25-34 anni
# 1309    Liguria  totale  97.624    25-34 anni
#
# [400 rows x 4 columns]

# %%
provapdef=totale.groupby(["Territorio", "Classe di età"]).sum()
provapdef
# Out:
#                                                 Valori
# Territorio                     Classe di età
# Abruzzo                        15-24 anni      205.276
#                                25-34 anni      946.200
# Basilicata                     15-24 anni       76.077
#                                25-34 anni      346.037
# Calabria                       15-24 anni      233.115
#                                25-34 anni     1028.428
# Campania                       15-24 anni      798.937
#                                25-34 anni     3031.088
# Emilia-Romagna                 15-24 anni      858.762
#                                25-34 anni     3554.942
# Friuli-Venezia Giulia          15-24 anni      215.318
#                                25-34 anni      900.229
# Lazio                          15-24 anni      838.096
#                                25-34 anni     4245.287
# Liguria                        15-24 anni      224.958
#                                25-34 anni     1012.250
# Lombardia                      15-24 anni     2036.398
#                                25-34 anni     8513.566
# Marche                         15-24 anni      288.988
#                                25-34 anni     1206.264
# Molise                         15-24 anni       41.283
#                                25-34 anni      190.576
# Piemonte                       15-24 anni      793.282
#                                25-34 anni     3360.170
# Puglia                         15-24 anni      633.220
#                                25-34 anni     2406.065
# Sardegna                       15-24 anni      223.723
#                                25-34 anni     1009.841
# Sicilia                        15-24 anni      662.605
#                                25-34 anni     2579.627
# Toscana                        15-24 anni      654.748
#                                25-34 anni     2796.418
# Trentino Alto Adige / Südtirol 15-24 anni      338.488
#                                25-34 anni      946.247
# Umbria                         15-24 anni      154.184
#                                25-34 anni      680.970
# Valle d'Aosta / Vallée d'Aoste 15-24 anni       26.244
#                                25-34 anni      102.095
# Veneto                         15-24 anni     1099.820
#                                25-34 anni     4014.560

# %% [markdown]
# Sulla base del dataset provapdef contenente solo i valori totali non suddivisi tra "maschi" e "femmine" andiamo a calcolare alcuni dati statistici che potranno tornarci utili successivamente per l'analisi

# %%
Datistat = np.array(totale['Valori'])
print(Datistat)
# Out:
# [ 92.305  93.164  88.688  71.562  70.225  70.483  68.945  75.233  80.328
#   82.349   3.082   2.705   2.914   2.513   2.233   2.519   2.502   2.463
#    2.643   2.67   27.534  27.416  26.923  18.956  19.195  19.604  20.793
#   21.364  21.012  22.161 223.118 215.549 207.712 194.263 187.38  177.93
#  186.144 197.4   216.685 230.217  35.203  35.36   36.13   32.384  31.824
#   29.66   31.473  33.001  35.549  37.904  25.822  23.623  19.145  20.959
#   21.018  19.608  20.655  20.973  20.461  23.054  91.704  88.425  87.152
#   72.344  72.155  77.612  88.166  91.272  92.158  97.774  70.455  68.999
#   67.905  65.508  64.229  61.09   58.767  66.123  64.537  67.135  19.831
#   19.153  17.005  14.813  12.771  13.903  13.846  14.989  13.777  14.096
#   35.961  29.745  31.083  25.668  24.548  27.053  28.277  30.335  28.451
#   27.867 101.963  94.395  85.229  75.711  69.21   76.572  78.139  81.465
#   88.492  86.92   88.083  77.278  73.404  59.092  51.001  56.241  60.321
#   53.14   57.194  57.466   8.178   8.63    7.489   5.483   7.241   7.412
#    8.972   7.232   7.411   8.029  26.334  27.003  25.026  24.473  22.062
#   17.     18.93   18.745  25.036  28.506  86.007  80.7    72.12   63.318
#   60.121  63.1    62.593  63.158  55.152  56.336 124.548 119.313 113.744
#  100.296 101.025  95.806 106.66  110.752 107.49  120.186  22.285  25.053
#   27.258  20.053  15.574  17.025  18.716  19.108  21.365  18.839   5.337
#    5.191   4.546   4.068   3.394   3.722   4.272   3.579   3.891   3.283
#   91.077  79.349  88.009  84.279  72.082  72.93   83.997  74.346  71.742
#   81.126  32.498  28.222  25.427  20.019  22.167  18.456  15.329  19.511
#   23.104  18.99   12.047  11.568  11.071  10.098   9.883   9.676   9.333
#    9.574   9.509   9.336 956.353 915.932 878.392 840.458 822.227 818.224
#  822.39  828.016 808.591 822.983 100.802  99.551  96.191  94.727  91.743
#   91.764  91.457  92.705  94.079  93.228 468.989 449.997 421.268 388.828
#  391.664 377.104 374.134 379.107 383.959 379.51  107.554 102.321  96.241
#   88.325  85.489  83.514  83.462  83.481  85.018  84.824 405.913 397.89
#  382.044 362.508 336.663 328.775 335.331 328.843 336.056 340.919 142.36
#  136.107 128.775 123.306 121.717 114.21  108.061 107.464 113.793 110.471
#   22.799  21.288  20.302  17.26   17.166  18.26   19.548  17.96   17.346
#   18.647  37.182  38.237  36.185  33.252  31.389  34.168  34.199  32.832
#   34.023  34.57  123.62  122.134 112.314  94.225  88.533  95.348  89.561
#   89.258  94.611 100.237 109.166 104.617 106.241  95.855  90.625  85.615
#   87.092  89.763  90.547  86.679 118.017 115.602 113.888  96.742  97.885
#   93.761  90.698  96.251 104.243 101.341 295.24  294.542 276.271 245.01
#  234.501 252.347 253.057 247.299 238.331 243.029 281.539 281.79  271.823
#  232.496 227.143 220.1   218.195 225.141 227.536 220.302 464.513 445.207
#  440.172 419.122 425.088 416.362 413.937 418.352 404.246 398.288  80.028
#   76.826  73.115  69.035  64.983  66.323  64.598  61.998  61.382  62.682
#  396.856 386.28  361.604 329.255 315.651 316.045 311.439 311.518 313.992
#  317.53  323.981 309.337 290.653 277.85  270.232 266.203 271.398 263.906
#  258.47  264.388 316.944 314.613 307.886 290.208 287.148 296.209 303.939
#  314.126 301.079 298.936 116.663 115.092 106.904  98.71   95.835  95.891
#   92.441  94.548  98.542  97.624]

# %%
#per vedere dati statistici posso utilizzare
print("Media giovani occupati: ", Datistat.mean())
print("Deviazione Standard: ", Datistat.std())
print("Valore minimo: ", Datistat.min())
print("Valore massimo: ", Datistat.max())
print("25 percentile: ", np.percentile(Datistat, 25))
print("Mediana Valori: ", np.median(Datistat))
print("75 percentile: ", np.percentile(Datistat, 75))
# Out:
# Media giovani occupati:  133.185955
# Deviazione Standard:  163.93264362015572
# Valore minimo:  2.233
# Valore massimo:  956.3530000000001
# 25 percentile:  25.3335
# Mediana Valori:  83.4715
# 75 percentile:  151.2525

# %% [markdown]
# **Importiamo matplotlib e seaborn per creare grafici sulla base dei nostri dati:**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set(context='notebook', style='darkgrid', font='sans-serif', font_scale = 1)
import seaborn as sns
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
seaborn.set_style(style="whitegrid")
plt.hist(Datistat)
plt.title('Dati statistici occupazione giovanile') #titolo del grafico
plt.xlabel('Valori') #nome asse x
# Out:
# Text(0.5, 0, 'Valori')

# %% [markdown]
# **COMMENTO GRAFICO**: *Il grafico sopra riportato mostra l'andamento dell'occupazione giovanile (presi i valori totali) distribuita nei diversi anni (dal 2010 al 2019); come si può notare c'è stata un'alta occupazione negli anni 2010 e 2011 e poi è andata calando fino ad avere una leggera ripresa nel 2018 e 2019*

# %%
sns.set_theme(style="darkgrid")

# %%
fig = plt.figure(figsize=(10,2))
sns.catplot(data=primo_data, x="Valori", y="Territorio", kind="bar", palette="ch:.25")

# %%
sns.barplot(data=totale, x="Valori", y="Territorio", palette="Blues_d", hue="Sesso")

# %%
sns.catplot(data=primo_data, x="Valori", y="Territorio", hue="Sesso", col="Sesso",kind="bar",height=4, aspect=.8)

# %%
sns.scatterplot(x="Valori", y="Territorio", data=sesso_femmine, color="red");
sns.scatterplot(x="Valori", y="Territorio", data=sesso_maschi, color="blue");
plt.show()

# %%
sns.color_palette()
sns.relplot(data=provapdef, x="Classe di età", y="Valori", kind="line", hue="Territorio", size="Territorio",sizes=(2,2)) #oppure kind="scatter"
plt.show()

# %% [markdown]
# **COMMENTO GRAFICO**: *Il grafico rappresenta l'occupazione per regione dividendo le due classi di età 15-24 e 25-34. Come si evince, la seconda classe di età presenta valori occupazionali di gran lunga maggiori rispetto alla classe di età inferiore pertanto, in conclusione, possiamo dire che con l'aumento dell'età è proporzionale all'aumento dell'occupazione*

# %% [markdown]
# **Importiamo il Dataset "tasso scolarità" dei giovani tra i 15 - 34 anni divisi titolo di studio (lo si trova sempre sul sito di Giovanistat)**

# %%
tasso_scolarità = pd.read_csv("C:/Users/lalla/Desktop/UNIMI/Tasso scolarità.csv")
tasso_scolarità
# Out:
#      ITTER107 Territorio TIPO_DATO_FOL  \
# 0          IT     Italia        POP_15
# 1          IT     Italia        POP_15
# 2          IT     Italia        POP_15
# 3          IT     Italia        POP_15
# 4          IT     Italia        POP_15
# ...       ...        ...           ...
# 1303       IT     Italia        POP_15
# 1304       IT     Italia        POP_15
# 1305       IT     Italia        POP_15
# 1306       IT     Italia        POP_15
# 1307       IT     Italia        POP_15
#
#                                    Tipo dato  SEXISTAT1   Sesso    ETA1  \
# 0     popolazione 15 anni e oltre (migliaia)          1  maschi  Y15-24
# 1     popolazione 15 anni e oltre (migliaia)          1  maschi  Y15-24
# 2     popolazione 15 anni e oltre (migliaia)          1  maschi  Y15-24
# 3     popolazione 15 anni e oltre (migliaia)          1  maschi  Y15-24
# 4     popolazione 15 anni e oltre (migliaia)          1  maschi  Y15-24
# ...                                      ...        ...     ...     ...
# 1303  popolazione 15 anni e oltre (migliaia)          9  totale  Y25-34
# 1304  popolazione 15 anni e oltre (migliaia)          9  totale  Y25-34
# 1305  popolazione 15 anni e oltre (migliaia)          9  totale  Y25-34
# 1306  popolazione 15 anni e oltre (migliaia)          9  totale  Y25-34
# 1307  popolazione 15 anni e oltre (migliaia)          9  totale  Y25-34
#
#      Classe di età  TITOLO_STUDIO  \
# 0       15-24 anni              3
# 1       15-24 anni              3
# 2       15-24 anni              3
# 3       15-24 anni              3
# 4       15-24 anni              3
# ...            ...            ...
# 1303    25-34 anni             99
# 1304    25-34 anni             99
# 1305    25-34 anni             99
# 1306    25-34 anni             99
# 1307    25-34 anni             99
#
#                                        Titolo di studio CITTADINANZA  \
# 0     licenza di scuola elementare, nessun titolo di...        TOTAL
# 1     licenza di scuola elementare, nessun titolo di...        TOTAL
# 2     licenza di scuola elementare, nessun titolo di...        TOTAL
# 3     licenza di scuola elementare, nessun titolo di...        TOTAL
# 4     licenza di scuola elementare, nessun titolo di...        TOTAL
# ...                                                 ...          ...
# 1303                                             totale        TOTAL
# 1304                                             totale        TOTAL
# 1305                                             totale        TOTAL
# 1306                                             totale        TOTAL
# 1307                                             totale        TOTAL
#
#      Cittadinanza     TIME Seleziona periodo     Value  Flag Codes  Flags
# 0          totale     2010              2010    57.725         NaN    NaN
# 1          totale  2010-Q2           T2-2010    70.229         NaN    NaN
# 2          totale  2010-Q1           T1-2010    75.314         NaN    NaN
# 3          totale  2010-Q4           T4-2010    44.196         NaN    NaN
# 4          totale  2010-Q3           T3-2010    41.161         NaN    NaN
# ...           ...      ...               ...       ...         ...    ...
# 1303       totale  2019-Q2           T2-2019  6542.816         NaN    NaN
# 1304       totale  2019-Q4           T4-2019  6507.638         NaN    NaN
# 1305       totale  2019-Q3           T3-2019  6519.996         NaN    NaN
# 1306       totale  2020-Q2           T2-2020  6472.912         NaN    NaN
# 1307       totale  2020-Q1           T1-2020  6493.784         NaN    NaN
#
# [1308 rows x 17 columns]

# %%
tasso_scolarità.isnull().sum()
# Out:
# ITTER107                0
# Territorio              0
# TIPO_DATO_FOL           0
# Tipo dato               0
# SEXISTAT1               0
# Sesso                   0
# ETA1                    0
# Classe di età           0
# TITOLO_STUDIO           0
# Titolo di studio        0
# CITTADINANZA            0
# Cittadinanza            0
# TIME                    0
# Seleziona periodo       0
# Value                   0
# Flag Codes           1308
# Flags                1308
# dtype: int64

# %% [markdown]
# **Tutti i valori di "Flag Codes" e "Flag" sono nulli (1320) pertanto eliminiamo le due colonne perchè non ci interessano per la nostra analisi e creiamo un nuovo dataset con le colonne che ci interessano**

# %%
#ts = tasso di scolarità
ts= pd.DataFrame(data=tasso_scolarità, columns =['Territorio', 'Sesso', 'Classe di età', 'Titolo di studio','Seleziona periodo', 'Value' ])
ts
# Out:
#      Territorio   Sesso Classe di età  \
# 0        Italia  maschi    15-24 anni
# 1        Italia  maschi    15-24 anni
# 2        Italia  maschi    15-24 anni
# 3        Italia  maschi    15-24 anni
# 4        Italia  maschi    15-24 anni
# ...         ...     ...           ...
# 1303     Italia  totale    25-34 anni
# 1304     Italia  totale    25-34 anni
# 1305     Italia  totale    25-34 anni
# 1306     Italia  totale    25-34 anni
# 1307     Italia  totale    25-34 anni
#
#                                        Titolo di studio Seleziona periodo  \
# 0     licenza di scuola elementare, nessun titolo di...              2010
# 1     licenza di scuola elementare, nessun titolo di...           T2-2010
# 2     licenza di scuola elementare, nessun titolo di...           T1-2010
# 3     licenza di scuola elementare, nessun titolo di...           T4-2010
# 4     licenza di scuola elementare, nessun titolo di...           T3-2010
# ...                                                 ...               ...
# 1303                                             totale           T2-2019
# 1304                                             totale           T4-2019
# 1305                                             totale           T3-2019
# 1306                                             totale           T2-2020
# 1307                                             totale           T1-2020
#
#          Value
# 0       57.725
# 1       70.229
# 2       75.314
# 3       44.196
# 4       41.161
# ...        ...
# 1303  6542.816
# 1304  6507.638
# 1305  6519.996
# 1306  6472.912
# 1307  6493.784
#
# [1308 rows x 6 columns]

# %%
ts.rename(columns={"Seleziona periodo": "Periodo"},inplace=True) 
ts
# Out:
#      Territorio   Sesso Classe di età  \
# 0        Italia  maschi    15-24 anni
# 1        Italia  maschi    15-24 anni
# 2        Italia  maschi    15-24 anni
# 3        Italia  maschi    15-24 anni
# 4        Italia  maschi    15-24 anni
# ...         ...     ...           ...
# 1303     Italia  totale    25-34 anni
# 1304     Italia  totale    25-34 anni
# 1305     Italia  totale    25-34 anni
# 1306     Italia  totale    25-34 anni
# 1307     Italia  totale    25-34 anni
#
#                                        Titolo di studio  Periodo     Value
# 0     licenza di scuola elementare, nessun titolo di...     2010    57.725
# 1     licenza di scuola elementare, nessun titolo di...  T2-2010    70.229
# 2     licenza di scuola elementare, nessun titolo di...  T1-2010    75.314
# 3     licenza di scuola elementare, nessun titolo di...  T4-2010    44.196
# 4     licenza di scuola elementare, nessun titolo di...  T3-2010    41.161
# ...                                                 ...      ...       ...
# 1303                                             totale  T2-2019  6542.816
# 1304                                             totale  T4-2019  6507.638
# 1305                                             totale  T3-2019  6519.996
# 1306                                             totale  T2-2020  6472.912
# 1307                                             totale  T1-2020  6493.784
#
# [1308 rows x 6 columns]

# %%
ts.rename(columns={"Value": "Valori"},inplace=True) 
ts
# Out:
#      Territorio   Sesso Classe di età  \
# 0        Italia  maschi    15-24 anni
# 1        Italia  maschi    15-24 anni
# 2        Italia  maschi    15-24 anni
# 3        Italia  maschi    15-24 anni
# 4        Italia  maschi    15-24 anni
# ...         ...     ...           ...
# 1303     Italia  totale    25-34 anni
# 1304     Italia  totale    25-34 anni
# 1305     Italia  totale    25-34 anni
# 1306     Italia  totale    25-34 anni
# 1307     Italia  totale    25-34 anni
#
#                                        Titolo di studio  Periodo    Valori
# 0     licenza di scuola elementare, nessun titolo di...     2010    57.725
# 1     licenza di scuola elementare, nessun titolo di...  T2-2010    70.229
# 2     licenza di scuola elementare, nessun titolo di...  T1-2010    75.314
# 3     licenza di scuola elementare, nessun titolo di...  T4-2010    44.196
# 4     licenza di scuola elementare, nessun titolo di...  T3-2010    41.161
# ...                                                 ...      ...       ...
# 1303                                             totale  T2-2019  6542.816
# 1304                                             totale  T4-2019  6507.638
# 1305                                             totale  T3-2019  6519.996
# 1306                                             totale  T2-2020  6472.912
# 1307                                             totale  T1-2020  6493.784
#
# [1308 rows x 6 columns]

# %% [markdown]
# Nella colonna "Periodo" ci sono dei valori contenenti la lettera T che però non ci interessano per la nostra analisi pertanto li togliamo

# %%
ts=ts[~ts.Periodo.str.contains("T")]
ts
# Out:
#      Territorio   Sesso Classe di età  \
# 0        Italia  maschi    15-24 anni
# 5        Italia  maschi    15-24 anni
# 10       Italia  maschi    15-24 anni
# 15       Italia  maschi    15-24 anni
# 20       Italia  maschi    15-24 anni
# ...         ...     ...           ...
# 1281     Italia  totale    25-34 anni
# 1286     Italia  totale    25-34 anni
# 1291     Italia  totale    25-34 anni
# 1296     Italia  totale    25-34 anni
# 1301     Italia  totale    25-34 anni
#
#                                        Titolo di studio Periodo    Valori
# 0     licenza di scuola elementare, nessun titolo di...    2010    57.725
# 5     licenza di scuola elementare, nessun titolo di...    2011    52.413
# 10    licenza di scuola elementare, nessun titolo di...    2012    56.919
# 15    licenza di scuola elementare, nessun titolo di...    2013    51.859
# 20    licenza di scuola elementare, nessun titolo di...    2014    45.993
# ...                                                 ...     ...       ...
# 1281                                             totale    2015  6837.353
# 1286                                             totale    2016  6760.848
# 1291                                             totale    2017  6677.184
# 1296                                             totale    2018  6607.820
# 1301                                             totale    2019  6532.872
#
# [300 rows x 6 columns]

# %%
ts1=ts.groupby(["Sesso", "Classe di età", "Titolo di studio","Periodo","Valori"]).sum()
ts1
# Out:
#                                                         Territorio
# Sesso   Classe di età Titolo di studio Periodo Valori
# femmine 15-24 anni    diploma          2010    1294.455     Italia
#                                        2011    1305.399     Italia
#                                        2012    1318.735     Italia
#                                        2013    1328.669     Italia
#                                        2014    1311.619     Italia
# ...                                                            ...
# totale  25-34 anni    totale           2015    6837.353     Italia
#                                        2016    6760.848     Italia
#                                        2017    6677.184     Italia
#                                        2018    6607.820     Italia
#                                        2019    6532.872     Italia
#
# [300 rows x 1 columns]

# %% [markdown]
# **La tabella non ci evidenzia il sesso maschile ma in realtà i valori ci sono (vedi sotto):**

# %%
ts2=ts1.groupby(["Sesso"]).count().reset_index()
ts2["Sesso"]
# Out:
# 0    femmine
# 1     maschi
# 2     totale
# Name: Sesso, dtype: object

# %%
ts3=ts.groupby(["Titolo di studio"]).sum()
ts3
# Out:
#                                                         Valori
# Titolo di studio
# diploma                                             119550.989
# laurea e post-laurea                                 38336.361
# licenza di scuola elementare, nessun titolo di ...    4933.258
# licenza di scuola media                              94224.796
# totale                                              257045.401

# %%
#x = np.array([119550.989, 38336.361, 4933.258, 94224.796])
fracs = [47, 15, 2, 36]
label = ["diploma", "laurea e post-laurea", "licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media"]
plt.pie(fracs, labels=label)
plt.show()

# %%
ts4=ts.groupby(["Titolo di studio","Periodo" ]).sum()
ts4
# Out:
#                                                                Valori
# Titolo di studio                                   Periodo
# diploma                                            2010     12554.662
#                                                    2011     12420.473
#                                                    2012     12231.868
#                                                    2013     12200.951
#                                                    2014     12084.105
#                                                    2015     11904.191
#                                                    2016     11684.760
#                                                    2017     11581.684
#                                                    2018     11427.278
#                                                    2019     11461.017
# laurea e post-laurea                               2010      3466.648
#                                                    2011      3444.130
#                                                    2012      3605.293
#                                                    2013      3649.452
#                                                    2014      3827.076
#                                                    2015      3892.945
#                                                    2016      3933.137
#                                                    2017      4094.818
#                                                    2018      4210.588
#                                                    2019      4212.274
# licenza di scuola elementare, nessun titolo di ... 2010       647.097
#                                                    2011       605.606
#                                                    2012       577.934
#                                                    2013       563.692
#                                                    2014       509.874
#                                                    2015       453.811
#                                                    2016       434.404
#                                                    2017       399.166
#                                                    2018       383.606
#                                                    2019       358.068
# licenza di scuola media                            2010     10213.548
#                                                    2011     10017.553
#                                                    2012      9770.602
#                                                    2013      9570.808
#                                                    2014      9348.418
#                                                    2015      9297.077
#                                                    2016      9276.608
#                                                    2017      9035.421
#                                                    2018      8917.788
#                                                    2019      8776.973
# totale                                             2010     26881.956
#                                                    2011     26487.762
#                                                    2012     26185.697
#                                                    2013     25984.904
#                                                    2014     25769.474
#                                                    2015     25548.020
#                                                    2016     25328.911
#                                                    2017     25111.089
#                                                    2018     24939.260
#                                                    2019     24808.328

# %% [markdown]
# **Creo un grafico a torta per ciascun anno suddiviso per titolo di studio, in modo da poter vedere in modo chiaro e lineare l'andamento del tasso di scolarità nel decennio 2010-2020**

# %%
#anno 2010 --> x = np.array([323.549, 5.106.774, 6.277.331, 1.733.324])
fracs = [2, 38, 47, 13]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2010') #titolo del grafico
plt.show()

#anno 2011 --> x = np.array([302.803, 5.008.777, 6.210.236, 1.722.065])
fracs = [2, 38, 47, 13]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2011') #titolo del grafico
plt.show()

#anno 2012 --> x = np.array([288.967, 4.885.301, 6.115.934, 1.802.647])
fracs = [2, 37, 47, 14]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2012') #titolo del grafico
plt.show()

#anno 2013 --> x = np.array([281.846, 4.785.404, 6.100.475, 1.824.726])
fracs = [2, 37, 47, 14]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2013') #titolo del grafico
plt.show()

#anno 2014 --> x = np.array([254.937, 4.674.209, 6.042.053, 1.913.538])
fracs = [2, 36, 47, 15]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2014') #titolo del grafico
plt.show()

#anno 2015 --> x = np.array([226.906, 4.648.539, 5.952.096, 1.946.473])
fracs = [2, 36, 47, 15]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2015') #titolo del grafico
plt.show()

#anno 2016 --> x = np.array([217.202, 4.638.304, 5.842.380, 1.966.568])
fracs = [2, 37, 46, 16]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2016') #titolo del grafico
plt.show()

#anno 2017 --> x = np.array([206.404, 4.557.317, 5.840.044, 2.002.046])
fracs = [2, 36, 46, 16]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2017') #titolo del grafico
plt.show()

#anno 2018 --> x = np.array([191.803, 4.458.894, 5.713.639, 2.105.294])
fracs = [2, 36, 46, 17]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2018') #titolo del grafico
plt.show()

#anno 2019 --> x = np.array([179.035, 4.388.487, 5.730.509, 2.106.137])
fracs = [1, 35, 46, 17]
label = ["licenza di scuola elementare, nessun titolo di studio", "licenza di scuola media","diploma", "laurea e post-laurea"]
plt.pie(fracs, labels=label)
plt.title('2019') #titolo del grafico
plt.show()

# %%
prova=ts[ts.Periodo.str.contains("2019")]
prova
# Out:
#      Territorio    Sesso Classe di età  \
# 45       Italia   maschi    15-24 anni
# 97       Italia   maschi    15-24 anni
# 113      Italia   maschi    15-24 anni
# 159      Italia   maschi    15-24 anni
# 211      Italia   maschi    15-24 anni
# 263      Italia  femmine    15-24 anni
# 315      Italia  femmine    15-24 anni
# 331      Italia  femmine    15-24 anni
# 377      Italia  femmine    15-24 anni
# 429      Italia  femmine    15-24 anni
# 481      Italia   totale    15-24 anni
# 533      Italia   totale    15-24 anni
# 549      Italia   totale    15-24 anni
# 595      Italia   totale    15-24 anni
# 647      Italia   totale    15-24 anni
# 699      Italia   maschi    25-34 anni
# 751      Italia   maschi    25-34 anni
# 767      Italia   maschi    25-34 anni
# 813      Italia   maschi    25-34 anni
# 865      Italia   maschi    25-34 anni
# 917      Italia  femmine    25-34 anni
# 969      Italia  femmine    25-34 anni
# 985      Italia  femmine    25-34 anni
# 1031     Italia  femmine    25-34 anni
# 1083     Italia  femmine    25-34 anni
# 1135     Italia   totale    25-34 anni
# 1187     Italia   totale    25-34 anni
# 1203     Italia   totale    25-34 anni
# 1249     Italia   totale    25-34 anni
# 1301     Italia   totale    25-34 anni
#
#                                        Titolo di studio Periodo    Valori
# 45    licenza di scuola elementare, nessun titolo di...    2019    34.123
# 97                              licenza di scuola media    2019  1564.645
# 113                                             diploma    2019  1331.304
# 159                                laurea e post-laurea    2019   122.414
# 211                                              totale    2019  3052.485
# 263   licenza di scuola elementare, nessun titolo di...    2019    23.962
# 315                             licenza di scuola media    2019  1366.418
# 331                                             diploma    2019  1253.603
# 377                                laurea e post-laurea    2019   174.825
# 429                                              totale    2019  2818.807
# 481   licenza di scuola elementare, nessun titolo di...    2019    58.084
# 533                             licenza di scuola media    2019  2931.062
# 549                                             diploma    2019  2584.906
# 595                                laurea e post-laurea    2019   297.239
# 647                                              totale    2019  5871.292
# 699   licenza di scuola elementare, nessun titolo di...    2019    70.019
# 751                             licenza di scuola media    2019   826.096
# 767                                             diploma    2019  1697.221
# 813                                laurea e post-laurea    2019   717.908
# 865                                              totale    2019  3311.243
# 917   licenza di scuola elementare, nessun titolo di...    2019    50.931
# 969                             licenza di scuola media    2019   631.328
# 985                                             diploma    2019  1448.381
# 1031                               laurea e post-laurea    2019  1090.990
# 1083                                             totale    2019  3221.629
# 1135  licenza di scuola elementare, nessun titolo di...    2019   120.949
# 1187                            licenza di scuola media    2019  1457.424
# 1203                                            diploma    2019  3145.602
# 1249                               laurea e post-laurea    2019  1808.898
# 1301                                             totale    2019  6532.872

# %% [markdown]
# **PROVA UNIONE DATAFRAME TASSO OCCUPAZIONE E TASSO DISOCCUPAZIONE**

# %%
tabella_iniziale_disoc= pd.read_csv("C:/Users/lalla/Desktop/UNIMI/Tasso disoccupazione.csv")
tabella_iniziale_disoc
# Out:
#      ITTER107 Territorio TIPO_DATO_FOL                Tipo dato  SEXISTAT1  \
# 0        ITC1   Piemonte        UNEM_R  tasso di disoccupazione          1
# 1        ITC1   Piemonte        UNEM_R  tasso di disoccupazione          1
# 2        ITC1   Piemonte        UNEM_R  tasso di disoccupazione          1
# 3        ITC1   Piemonte        UNEM_R  tasso di disoccupazione          1
# 4        ITC1   Piemonte        UNEM_R  tasso di disoccupazione          1
# ...       ...        ...           ...                      ...        ...
# 1315     ITE3     Marche        UNEM_R  tasso di disoccupazione          2
# 1316     ITE3     Marche        UNEM_R  tasso di disoccupazione          2
# 1317     ITE3     Marche        UNEM_R  tasso di disoccupazione          2
# 1318     ITE3     Marche        UNEM_R  tasso di disoccupazione          2
# 1319     ITE3     Marche        UNEM_R  tasso di disoccupazione          2
#
#         Sesso    ETA1 Classe di età  TIME  Seleziona periodo      Value  \
# 0      maschi  Y15-24    15-24 anni  2010               2010  26.669293
# 1      maschi  Y15-24    15-24 anni  2011               2011  23.777270
# 2      maschi  Y15-24    15-24 anni  2012               2012  29.870147
# 3      maschi  Y15-24    15-24 anni  2013               2013  40.233077
# 4      maschi  Y15-24    15-24 anni  2014               2014  41.636268
# ...       ...     ...           ...   ...                ...        ...
# 1315  femmine  Y15-24    15-24 anni  2015               2015  36.901490
# 1316  femmine  Y15-24    15-24 anni  2016               2016  37.043544
# 1317  femmine  Y15-24    15-24 anni  2017               2017  27.681294
# 1318  femmine  Y15-24    15-24 anni  2018               2018  28.532478
# 1319  femmine  Y15-24    15-24 anni  2019               2019  32.129859
#
#       Flag Codes  Flags
# 0            NaN    NaN
# 1            NaN    NaN
# 2            NaN    NaN
# 3            NaN    NaN
# 4            NaN    NaN
# ...          ...    ...
# 1315         NaN    NaN
# 1316         NaN    NaN
# 1317         NaN    NaN
# 1318         NaN    NaN
# 1319         NaN    NaN
#
# [1320 rows x 13 columns]

# %%
tabella_iniziale_disoc.isnull().sum()
# Out:
# ITTER107                0
# Territorio              0
# TIPO_DATO_FOL           0
# Tipo dato               0
# SEXISTAT1               0
# Sesso                   0
# ETA1                    0
# Classe di età           0
# TIME                    0
# Seleziona periodo       0
# Value                   0
# Flag Codes           1320
# Flags                1320
# dtype: int64

# %%
tasso_disoccupazione_giovanile= pd.DataFrame(data=tabella_iniziale_disoc, columns =['Territorio', 'SEXISTAT1', 'Sesso', 'Classe di età', 'Seleziona periodo', 'Value' ])
tasso_disoccupazione_giovanile
# Out:
#      Territorio  SEXISTAT1    Sesso Classe di età  Seleziona periodo  \
# 0      Piemonte          1   maschi    15-24 anni               2010
# 1      Piemonte          1   maschi    15-24 anni               2011
# 2      Piemonte          1   maschi    15-24 anni               2012
# 3      Piemonte          1   maschi    15-24 anni               2013
# 4      Piemonte          1   maschi    15-24 anni               2014
# ...         ...        ...      ...           ...                ...
# 1315     Marche          2  femmine    15-24 anni               2015
# 1316     Marche          2  femmine    15-24 anni               2016
# 1317     Marche          2  femmine    15-24 anni               2017
# 1318     Marche          2  femmine    15-24 anni               2018
# 1319     Marche          2  femmine    15-24 anni               2019
#
#           Value
# 0     26.669293
# 1     23.777270
# 2     29.870147
# 3     40.233077
# 4     41.636268
# ...         ...
# 1315  36.901490
# 1316  37.043544
# 1317  27.681294
# 1318  28.532478
# 1319  32.129859
#
# [1320 rows x 6 columns]

# %%
tasso_disoccupazione_giovanile.rename(columns={"Value": "Valori"},inplace=True) 
tasso_disoccupazione_giovanile
# Out:
#      Territorio  SEXISTAT1    Sesso Classe di età  Seleziona periodo  \
# 0      Piemonte          1   maschi    15-24 anni               2010
# 1      Piemonte          1   maschi    15-24 anni               2011
# 2      Piemonte          1   maschi    15-24 anni               2012
# 3      Piemonte          1   maschi    15-24 anni               2013
# 4      Piemonte          1   maschi    15-24 anni               2014
# ...         ...        ...      ...           ...                ...
# 1315     Marche          2  femmine    15-24 anni               2015
# 1316     Marche          2  femmine    15-24 anni               2016
# 1317     Marche          2  femmine    15-24 anni               2017
# 1318     Marche          2  femmine    15-24 anni               2018
# 1319     Marche          2  femmine    15-24 anni               2019
#
#          Valori
# 0     26.669293
# 1     23.777270
# 2     29.870147
# 3     40.233077
# 4     41.636268
# ...         ...
# 1315  36.901490
# 1316  37.043544
# 1317  27.681294
# 1318  28.532478
# 1319  32.129859
#
# [1320 rows x 6 columns]

# %%
tasso_occupazione_giovanile
# Out:
#      Territorio  SEXISTAT1    Sesso Classe di età  Seleziona periodo  Valori
# 0      Piemonte          1   maschi    15-24 anni               2010  52.110
# 1      Piemonte          1   maschi    15-24 anni               2011  54.017
# 2      Piemonte          1   maschi    15-24 anni               2012  52.224
# 3      Piemonte          1   maschi    15-24 anni               2013  42.618
# 4      Piemonte          1   maschi    15-24 anni               2014  39.999
# ...         ...        ...      ...           ...                ...     ...
# 1315     Umbria          2  femmine    25-34 anni               2015  28.447
# 1316     Umbria          2  femmine    25-34 anni               2016  29.167
# 1317     Umbria          2  femmine    25-34 anni               2017  26.733
# 1318     Umbria          2  femmine    25-34 anni               2018  24.818
# 1319     Umbria          2  femmine    25-34 anni               2019  28.554
#
# [1320 rows x 6 columns]

# %%
#TDG=tasso disoccupazione giovanile
TDG_regioni=tasso_disoccupazione_giovanile[~tasso_disoccupazione_giovanile.Territorio.str.contains("Provincia")]
TDG_regioni
# Out:
#      Territorio  SEXISTAT1    Sesso Classe di età  Seleziona periodo  \
# 0      Piemonte          1   maschi    15-24 anni               2010
# 1      Piemonte          1   maschi    15-24 anni               2011
# 2      Piemonte          1   maschi    15-24 anni               2012
# 3      Piemonte          1   maschi    15-24 anni               2013
# 4      Piemonte          1   maschi    15-24 anni               2014
# ...         ...        ...      ...           ...                ...
# 1315     Marche          2  femmine    15-24 anni               2015
# 1316     Marche          2  femmine    15-24 anni               2016
# 1317     Marche          2  femmine    15-24 anni               2017
# 1318     Marche          2  femmine    15-24 anni               2018
# 1319     Marche          2  femmine    15-24 anni               2019
#
#          Valori
# 0     26.669293
# 1     23.777270
# 2     29.870147
# 3     40.233077
# 4     41.636268
# ...         ...
# 1315  36.901490
# 1316  37.043544
# 1317  27.681294
# 1318  28.532478
# 1319  32.129859
#
# [1200 rows x 6 columns]

# %%
primo_data_disoc=TDG_regioni[['Territorio','Sesso','Valori','Classe di età']]
primo_data_disoc
# Out:
#      Territorio    Sesso     Valori Classe di età
# 0      Piemonte   maschi  26.669293    15-24 anni
# 1      Piemonte   maschi  23.777270    15-24 anni
# 2      Piemonte   maschi  29.870147    15-24 anni
# 3      Piemonte   maschi  40.233077    15-24 anni
# 4      Piemonte   maschi  41.636268    15-24 anni
# ...         ...      ...        ...           ...
# 1315     Marche  femmine  36.901490    15-24 anni
# 1316     Marche  femmine  37.043544    15-24 anni
# 1317     Marche  femmine  27.681294    15-24 anni
# 1318     Marche  femmine  28.532478    15-24 anni
# 1319     Marche  femmine  32.129859    15-24 anni
#
# [1200 rows x 4 columns]

# %%
totale2=primo_data_disoc[primo_data_disoc.Sesso == "totale"]
totale2
# Out:
#      Territorio   Sesso     Valori Classe di età
# 20     Piemonte  totale  26.645422    15-24 anni
# 21     Piemonte  totale  24.973022    15-24 anni
# 22     Piemonte  totale  32.079402    15-24 anni
# 23     Piemonte  totale  40.640527    15-24 anni
# 24     Piemonte  totale  42.233026    15-24 anni
# ...         ...     ...        ...           ...
# 1295   Calabria  totale  36.225437    25-34 anni
# 1296   Calabria  totale  38.808266    25-34 anni
# 1297   Calabria  totale  34.371335    25-34 anni
# 1298   Calabria  totale  29.761071    25-34 anni
# 1299   Calabria  totale  30.577420    25-34 anni
#
# [400 rows x 4 columns]

# %%
totale=primo_data[primo_data.Sesso == "totale"]
totale
# Out:
#      Territorio   Sesso  Valori Classe di età
# 20     Piemonte  totale  92.305    15-24 anni
# 21     Piemonte  totale  93.164    15-24 anni
# 22     Piemonte  totale  88.688    15-24 anni
# 23     Piemonte  totale  71.562    15-24 anni
# 24     Piemonte  totale  70.225    15-24 anni
# ...         ...     ...     ...           ...
# 1305    Liguria  totale  95.891    25-34 anni
# 1306    Liguria  totale  92.441    25-34 anni
# 1307    Liguria  totale  94.548    25-34 anni
# 1308    Liguria  totale  98.542    25-34 anni
# 1309    Liguria  totale  97.624    25-34 anni
#
# [400 rows x 4 columns]

# %%
provapdef=totale.groupby(["Territorio", "Classe di età"]).sum()
provapdef
# Out:
#                                                 Valori
# Territorio                     Classe di età
# Abruzzo                        15-24 anni      205.276
#                                25-34 anni      946.200
# Basilicata                     15-24 anni       76.077
#                                25-34 anni      346.037
# Calabria                       15-24 anni      233.115
#                                25-34 anni     1028.428
# Campania                       15-24 anni      798.937
#                                25-34 anni     3031.088
# Emilia-Romagna                 15-24 anni      858.762
#                                25-34 anni     3554.942
# Friuli-Venezia Giulia          15-24 anni      215.318
#                                25-34 anni      900.229
# Lazio                          15-24 anni      838.096
#                                25-34 anni     4245.287
# Liguria                        15-24 anni      224.958
#                                25-34 anni     1012.250
# Lombardia                      15-24 anni     2036.398
#                                25-34 anni     8513.566
# Marche                         15-24 anni      288.988
#                                25-34 anni     1206.264
# Molise                         15-24 anni       41.283
#                                25-34 anni      190.576
# Piemonte                       15-24 anni      793.282
#                                25-34 anni     3360.170
# Puglia                         15-24 anni      633.220
#                                25-34 anni     2406.065
# Sardegna                       15-24 anni      223.723
#                                25-34 anni     1009.841
# Sicilia                        15-24 anni      662.605
#                                25-34 anni     2579.627
# Toscana                        15-24 anni      654.748
#                                25-34 anni     2796.418
# Trentino Alto Adige / Südtirol 15-24 anni      338.488
#                                25-34 anni      946.247
# Umbria                         15-24 anni      154.184
#                                25-34 anni      680.970
# Valle d'Aosta / Vallée d'Aoste 15-24 anni       26.244
#                                25-34 anni      102.095
# Veneto                         15-24 anni     1099.820
#                                25-34 anni     4014.560

# %%
provadef_disoc=totale2.groupby(["Territorio", "Classe di età"]).sum()
provadef_disoc
# Out:
#                                                   Valori
# Territorio                     Classe di età
# Abruzzo                        15-24 anni     356.417163
#                                25-34 anni     168.228770
# Basilicata                     15-24 anni     423.359930
#                                25-34 anni     222.540685
# Calabria                       15-24 anni     528.408223
#                                25-34 anni     304.425253
# Campania                       15-24 anni     499.927160
#                                25-34 anni     288.965585
# Emilia-Romagna                 15-24 anni     248.258757
#                                25-34 anni      93.569480
# Friuli-Venezia Giulia          15-24 anni     246.416185
#                                25-34 anni     101.561208
# Lazio                          15-24 anni     384.714983
#                                25-34 anni     160.847964
# Liguria                        15-24 anni     330.110955
#                                25-34 anni     134.449718
# Lombardia                      15-24 anni     253.517272
#                                25-34 anni      83.494071
# Marche                         15-24 anni     272.893422
#                                25-34 anni     126.543062
# Molise                         15-24 anni     413.576565
#                                25-34 anni     220.700715
# Piemonte                       15-24 anni     330.327105
#                                25-34 anni     125.819685
# Puglia                         15-24 anni     457.764311
#                                25-34 anni     245.083367
# Sardegna                       15-24 anni     472.337142
#                                25-34 anni     253.430800
# Sicilia                        15-24 anni     517.433568
#                                25-34 anni     297.043057
# Toscana                        15-24 anni     283.351868
#                                25-34 anni     114.150181
# Trentino Alto Adige / Südtirol 15-24 anni     139.661397
#                                25-34 anni      57.583757
# Umbria                         15-24 anni     318.511645
#                                25-34 anni     132.758357
# Valle d'Aosta / Vallée d'Aoste 15-24 anni     258.257309
#                                25-34 anni      94.042084
# Veneto                         15-24 anni     218.613380
#                                25-34 anni      86.111095

# %%
unione=pd.merge(left=provapdef, right=provadef_disoc, how='outer',on=("Valori", "Territorio"))
unione
# Out:
#                                     Valori
# Territorio
# Abruzzo                         205.276000
# Abruzzo                         946.200000
# Basilicata                       76.077000
# Basilicata                      346.037000
# Calabria                        233.115000
# ...                                    ...
# Umbria                          132.758357
# Valle d'Aosta / Vallée d'Aoste  258.257309
# Valle d'Aosta / Vallée d'Aoste   94.042084
# Veneto                          218.613380
# Veneto                           86.111095
#
# [80 rows x 1 columns]

# %% [markdown]
# https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51 PER GRAFICO MEDIANA/MEDIA ECC
